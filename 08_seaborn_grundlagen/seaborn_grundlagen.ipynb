# %% [markdown]
# <h1>Inhaltsverzeichnis<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Einleitung" data-toc-modified-id="Einleitung-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Einleitung</a></span></li><li><span><a href="#Vergleich-Matplotlib-vs.-Seaborn" data-toc-modified-id="Vergleich-Matplotlib-vs.-Seaborn-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Vergleich Matplotlib vs. Seaborn</a></span><ul class="toc-item"><li><span><a href="#cumsum()-Hilfsfunktion" data-toc-modified-id="cumsum()-Hilfsfunktion-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span><code>cumsum() Hilfsfunktion</code></a></span></li><li><span><a href="#Mal-schnell-ein-paar-Random-Walks-erzeugen" data-toc-modified-id="Mal-schnell-ein-paar-Random-Walks-erzeugen-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Mal schnell ein paar Random Walks erzeugen</a></span></li><li><span><a href="#Matplotlib-Plot-für-die-Daten" data-toc-modified-id="Matplotlib-Plot-für-die-Daten-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Matplotlib Plot für die Daten</a></span></li><li><span><a href="#Seaborn-Plot-für-die-Daten" data-toc-modified-id="Seaborn-Plot-für-die-Daten-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Seaborn Plot für die Daten</a></span></li></ul></li><li><span><a href="#Histogramm-Plot" data-toc-modified-id="Histogramm-Plot-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Histogramm Plot</a></span></li><li><span><a href="#Eine-2D-Verteilung-plotten" data-toc-modified-id="Eine-2D-Verteilung-plotten-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Eine 2D Verteilung plotten</a></span></li></ul></div>

# %% [markdown]
# # Einleitung
#
# Seaborn ist ein Paket, das auf Matplotlib aufbaut und zur einfachen Generierung statistischer Plots gedacht ist.
#
# Von der GitHub Webseite:
#
# https://github.com/mwaskom/seaborn
#
# > Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.
#
# Und von der Webseite:
#
# https://pypi.org/project/seaborn/
#
# >Seaborn aims to make visualization a central part of exploring and understanding data. Its dataset-oriented plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots.

# %% [markdown]
# # Vergleich Matplotlib vs. Seaborn

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
#%matplotlib inline
import numpy as np
import pandas as pd

# %% [markdown]
# ## `cumsum() Hilfsfunktion`

# %% [markdown]
# Im folgenden benutzen wir eine Hilfsfunktion von NumPy Arrays namens `cumsum()` zum bilden von kummulierten Summen:

# %%
d = np.array( [10,20,30,40] )

# %%
d.cumsum(0)
# Out:
# array([ 10,  30,  60, 100], dtype=int32)

# %%
d = np.array( [[10,20,30,40], [5,5,5,5]] )

# %%
d
# Out:
# array([[10, 20, 30, 40],
#        [ 5,  5,  5,  5]])

# %% [markdown]
# Spaltenweise kummulierte Summe bilden:

# %%
d.cumsum(0)
# Out:
# array([[10, 20, 30, 40],
#        [15, 25, 35, 45]], dtype=int32)

# %% [markdown]
# Zeilenweise kummulierte Summe bilden:

# %%
d.cumsum(1)
# Out:
# array([[ 10,  30,  60, 100],
#        [  5,  10,  15,  20]], dtype=int32)

# %% [markdown]
# ## Mal schnell ein paar Random Walks erzeugen

# %% [markdown]
# Eine normalverteilte Zufallsmatrix mit 500 Zeilen und 4 Spalten erzeugen:

# %%
x = np.linspace(0, 10, 500)

rng = np.random.RandomState(0)
mat = rng.randn(500,4)

# %%
mat.shape
# Out:
# (500, 4)

# %%
mat
# Out:
# array([[ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ],
#        [ 1.86755799, -0.97727788,  0.95008842, -0.15135721],
#        [-0.10321885,  0.4105985 ,  0.14404357,  1.45427351],
#        ...,
#        [-1.25978734,  0.0286205 ,  1.34262201, -0.73993585],
#        [ 1.31513767, -0.32345747,  0.19782817,  0.0977508 ],
#        [ 1.40152342,  0.15843385, -1.14190142, -1.31097037]])

# %% [raw]
# Erzeugen einer weiteren Matrix, bei der wir für jede Spalte die kummulierte Summe bilden:

# %%
y = np.cumsum(rng.randn(500, 4), 0)

# %%
y.shape
# Out:
# (500, 4)

# %%
y
# Out:
# array([[ -1.53292105e+00,  -1.71197016e+00,   4.61350590e-02,
#          -9.58374480e-01],
#        [ -1.61373267e+00,  -2.41582920e+00,  -7.24649242e-01,
#          -1.43921982e+00],
#        [ -9.10147112e-01,  -1.48668405e+00,  -3.53476689e-01,
#          -2.42904237e+00],
#        ...,
#        [ -5.50156264e+01,   2.64494075e+01,  -1.58079459e+01,
#          -2.74931193e+01],
#        [ -5.49503208e+01,   2.56758947e+01,  -1.54129977e+01,
#          -2.79970092e+01],
#        [ -5.31707617e+01,   2.56453223e+01,  -1.38359095e+01,
#          -2.88098113e+01]])

# %% [markdown]
# ## Matplotlib Plot für die Daten

# %% [markdown]
# Plotten der Daten mittels Matplotlib:

# %%
plt.plot(x, y)
plt.legend('ABCD', ncol=2, loc='upper left')
plt.show()

# %% [markdown]
# ## Seaborn Plot für die Daten

# %%
import seaborn as sns
sns.set(style="darkgrid")

# %% [markdown]
# Wir können im folgenden den gleichen Code zum Plotten verwenden wie oben:

# %%
plt.plot(x, y)
plt.legend('ABCD', ncol=2, loc='upper left')
plt.show()

# %% [markdown]
# Der Plot ist aber (meines Erachtens) "irgendwie hübscher".

# %% [markdown]
# Es gibt auch Voreinstellungen für verschiedene Medien:

# %%
# {paper, notebook, talk, poster}
sns.set_context("paper")
plt.plot(x, y)
plt.legend('ABCD', ncol=2, loc='upper left')
plt.show()

# %%
# {paper, notebook, talk, poster}
sns.set_context("poster")
plt.plot(x, y)
plt.legend('ABCD', ncol=2, loc='upper left')
plt.show()

sns.set_context("notebook")

# %% [markdown]
# # Histogramm Plot

# %% [markdown]
# Wir erzeugen jetzt erstmal 2D normalverteilte Zufallsdaten:

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)

# %%
data
# Out:
# array([[-2.31646458, -1.26831804],
#        [-0.39376549,  0.1314189 ],
#        [ 0.19172396,  0.04832915],
#        ...,
#        [-1.68738339, -0.05035113],
#        [ 2.07886588,  1.66667921],
#        [ 0.1477538 , -1.09636446]])

# %%
data = pd.DataFrame(data, columns=['x', 'y'])

# %%
for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5)
plt.show()

# %% [markdown]
# Mit Seaborn können wir nun aus den Daten ein (geglättetes) Histogramm generieren (mittels eines sog. Kerndichteschätzers = Kernel Density Estimator = KDE):
#
# Das geht mit Seaborns `kdeplot()` Funktion:

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)
plt.ylim(0,0.3)
plt.show()

# %% [markdown]
# Es gibt auch eine Funktion in Seaborn, die beides in einem Rutsch kann: ein Histogramm aus Daten erzeugen und noch ein geglättetes dazu: `distplot()`

# %%
plt.clf()
sns.distplot(data['x'])
sns.distplot(data['y'])
plt.ylim(0,0.3)
plt.show()

# %% [markdown]
# # Eine 2D Verteilung plotten

# %% [markdown]
# Statt eines 1D Histogramms, können wir auch ein (geglättetes) 2D Histogramm erzeugen, um besser zu sehen, wo unsere Daten liegen:

# %%
sns.kdeplot( data['x'], data['y'] )
plt.show()

# %% [markdown]
# Wenn wir nicht nur die 2D Verteilung sehen wollen, sondern auch noch die zugehörigen projizierten 1D Verteilungen der x- bzw. y-Werte, können wir dies mit `jointplot()` tun:

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde')
plt.show()

# %% [markdown]
# Wir können hier auch einen anderen Stil für den `jointplot` wählen:

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')
plt.show()

# %% [markdown]
# Wenn wir bei dem Schalter `kind` gar nichts angeben, erhalten wir jeden Datenpunkt einzelnt gezeichnet:

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data)
plt.show()

# %%
type(sns)
# Out:
# module
